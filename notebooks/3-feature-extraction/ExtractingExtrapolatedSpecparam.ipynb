# %% [raw]
# ---
# title: "Untitled"
# format:
#   html:
#     page-layout: full
#     toc: true
#     toc-location: left
#     embed-resources: true
# ---

# %%
from specparam import SpectralGroupModel
from specparam.plts.spectra import plot_spectra
import mne
from spectral.utils import print_date_time, read_parameters, config_project
from pathlib import Path
import re
from spectral.specparam import specparam2pandas
import pandas as pd


def extract_numbers(bids_paths):
    # Initialize an empty list to store the numbers
    numbers = []

    # Get all the child directories
    for path in bids_paths.glob("*"):
        if path.is_dir():
            # Convert the path to a string
            str_path = str(path)

            # Find all three-digit numbers in the string
            matches = re.findall(r"\b\d{3}\b", str_path)

            # Add the numbers to the list
            numbers.extend(matches)

    # Now 'numbers' is a list of all three-digit numbers in the child directory names
    return sorted(numbers)


fg = SpectralGroupModel(
    peak_width_limits=[1, 6],
    min_peak_height=0.05,
    peak_threshold=2.0,
    max_n_peaks=6,
    verbose=False,
)

project_path = "/Users/daniel/Projects/psd-path"
specparam_path = f"{project_path}/analysis/data/specparam/2024-05-14_specparam"
bids_folder = Path(f"{project_path}/data/raw/BIDS/")
subjects = extract_numbers(bids_folder)
for subject in subjects:
    print(f"Processing subject {subject}")
    my_paths = config_project(subject)
    project_path = my_paths["project_path"]
    epochs_path = f"{project_path}/analysis/sub-{subject}_interpolated-epo.fif"
    epochs_ar = mne.read_epochs(epochs_path)
    # Print the number of channels
    print(f"Number of channels: {len(epochs_ar.info['ch_names'])}")

    # Print the bad channels
    print(f"Bad channels: {epochs_ar.info['bads']}")
    psd = epochs_ar.compute_psd().average()
    spectra, freqs = psd.get_data(return_freqs=True)
    # Initialize a FOOOFGroup object, with desired settings

    # Define the frequency range to fit
    freq_range = [2, 40]
    fg.fit(freqs, spectra, freq_range)
    channel_names = epochs_ar.info["ch_names"]
    df_channels = pd.DataFrame({"ID": range(len(channel_names)), "ch": channel_names})

    df = specparam2pandas(fg)
    df = df.merge(df_channels, on="ID")
    df["sub_id"] = subject
    # Define the new column order
    cols = ["sub_id", "ch"] + [col for col in df.columns if col not in ["sub_id", "ch"]]
    # Reindex the DataFrame
    df = df.reindex(columns=cols)
    df.to_csv(f"{specparam_path}/sub-{subject}-specparam.csv", index=False)
    print(f"Subject {subject} done")
# Out:
# Processing subject 101
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-101_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 76 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 101 done
# Processing subject 102
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-102_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 74 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 102 done
# Processing subject 103
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-103_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 77 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 103 done
# Processing subject 104
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-104_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 67 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 104 done
# Processing subject 105
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-105_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 65 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 105 done
# Processing subject 106
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-106_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 81 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 106 done
# Processing subject 107
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-107_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 111 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 107 done
# Processing subject 108
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-108_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 70 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 108 done
# Processing subject 109
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-109_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 63 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 109 done
# Processing subject 110
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-110_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 37 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 110 done
# Processing subject 111
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-111_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 66 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 111 done
# Processing subject 112
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-112_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 66 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 112 done
# Processing subject 113
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-113_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 113 done
# Processing subject 114
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-114_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 108 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 114 done
# Processing subject 115
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-115_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 81 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 115 done
# Processing subject 116
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-116_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 50 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 116 done
# Processing subject 118
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-118_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 76 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 118 done
# Processing subject 119
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-119_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 78 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 119 done
# Processing subject 120
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-120_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 81 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 120 done
# Processing subject 121
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-121_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 81 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 121 done
# Processing subject 122
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-122_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 67 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 122 done
# Processing subject 123
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-123_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 77 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 123 done
# Processing subject 124
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-124_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 62 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 124 done
# Processing subject 125
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-125_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 74 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 125 done
# Processing subject 126
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-126_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 40 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 126 done
# Processing subject 127
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-127_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 65 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 127 done
# Processing subject 128
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-128_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 62 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 128 done
# Processing subject 129
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-129_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 64 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 129 done
# Processing subject 131
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-131_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 76 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 131 done
# Processing subject 132
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-132_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 53 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 132 done
# Processing subject 134
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-134_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 68 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 134 done
# Processing subject 135
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-135_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 62 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 135 done
# Processing subject 136
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-136_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 59 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 136 done
# Processing subject 137
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-137_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 73 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 137 done
# Processing subject 138
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-138_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 138 done
# Processing subject 139
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-139_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 73 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 139 done
# Processing subject 140
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-140_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 57 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 140 done
# Processing subject 142
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-142_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 81 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 142 done
# Processing subject 143
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-143_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 84 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 143 done
# Processing subject 144
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-144_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 64 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 144 done
# Processing subject 145
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-145_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 73 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 145 done
# Processing subject 146
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-146_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 68 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 146 done
# Processing subject 147
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-147_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 66 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 147 done
# Processing subject 148
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-148_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 76 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 148 done
# Processing subject 149
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-149_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 149 done
# Processing subject 150
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-150_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 65 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 150 done
# Processing subject 151
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-151_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 71 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 151 done
# Processing subject 152
# Reading /Users/daniel/PhD/Projects/psd-path/analysis/sub-152_interpolated-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 79 matching events found
# No baseline correction applied
# 0 projection items activated
# Number of channels: 205
# Bad channels: []
#     Using multitaper spectrum estimation with 7 DPSS windows
# Subject 152 done
