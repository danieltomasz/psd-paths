# %%
# %load_ext autoreload
# %autoreload 2

# %%
# | tags: [parameters]
subject_id = "170"

# %%
# Parameters
subject_id = "119"

# %%
from IPython.display import display
from hamilton import telemetry

telemetry.disable_telemetry()

from hamilton import driver
from spectral import mne_pipeline
from spectral.helpers import style_cfg


filter_params = {
    "l_freq": 1.0,
    "h_freq": 45.0,
    "h_trans_bandwidth": "auto",
    "fir_window": "hamming",
    "fir_design": "firwin",
    "phase": "zero",
    "picks": ["ecg", "eeg"],
}

inputs = {"subject_id": subject_id , "fline": [50, 100], "filter_params": filter_params}

# Initialize Driver
dr = driver.Driver({}, mne_pipeline)



# 2. Display
dr.display_all_functions(orient="TB", custom_style_function=style_cfg)

# %%
results = dr.execute(
    final_vars=[ "raw_potatoed", "plot_raw_psd", "report_with_psd", "raw_filtered", "raw_annotated_pyprep", "plot_filtered_psd", "report_saved_path"],
    inputs=inputs,
)
# Out:
# Created directories for sub-119
# Project root: /Users/daniel/PhD/Projects/psd-paths
# Loading BrainVision data from: sub-119_ses-01_task-RESTING_eeg.vhdr
# Extracting parameters from /Users/daniel/PhD/Projects/psd-paths/data/bids/sub-119/ses-01/eeg/sub-119_ses-01_task-RESTING_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 300430  =      0.000 ...   300.430 secs...
# Loaded 258 channels, 300.4 seconds of data
# Identified ECG channels: ['ECG']
# Removed 'VREF' channel.
# Applying GSN-HydroCel-256 montage...
#    High-pass filtering > 0.5 Hz...
# Trying Potato with threshold=2.9...
# Potato fit successfully with threshold=2.9
# Found 37 bad segments.
# ✅ Added 37 'BAD_potato' annotations to the raw object.
# Setting 52931 of 294431 (17.98%) samples to NaN, retaining 241500 (82.02%) samples.
# Effective window size : 2.048 (s)
# At least one good data span is shorter than n_per_seg, and will be analyzed with a shorter window than the rest of the file.
# /Users/daniel/PhD/Projects/psd-paths/.venv/lib/python3.13/site-packages/mne/time_frequency/psd.py:291: UserWarning: nperseg = 2048 is greater than input length  = 1500, using nperseg = 1500
#   return _func(*args, **kwargs)
# /Users/daniel/PhD/Projects/psd-paths/.venv/lib/python3.13/site-packages/mne/time_frequency/psd.py:291: UserWarning: nperseg = 2048 is greater than input length  = 1500, using nperseg = 1500
#   return _func(*args, **kwargs)
# /Users/daniel/PhD/Projects/psd-paths/.venv/lib/python3.13/site-packages/mne/time_frequency/psd.py:291: UserWarning: nperseg = 2048 is greater than input length  = 1500, using nperseg = 1500
#   return _func(*args, **kwargs)
# /Users/daniel/PhD/Projects/psd-paths/.venv/lib/python3.13/site-packages/mne/time_frequency/psd.py:291: UserWarning: nperseg = 2048 is greater than input length  = 1500, using nperseg = 1500
#   return _func(*args, **kwargs)
# /Users/daniel/PhD/Projects/psd-paths/.venv/lib/python3.13/site-packages/mne/time_frequency/psd.py:291: UserWarning: nperseg = 2048 is greater than input length  = 1500, using nperseg = 1500
#   return _func(*args, **kwargs)
# /Users/daniel/PhD/Projects/psd-paths/.venv/lib/python3.13/site-packages/mne/time_frequency/psd.py:291: UserWarning: nperseg = 2048 is greater than input length  = 1500, using nperseg = 1500
#   return _func(*args, **kwargs)
# /Users/daniel/PhD/Projects/psd-paths/.venv/lib/python3.13/site-packages/mne/time_frequency/psd.py:291: UserWarning: nperseg = 2048 is greater than input length  = 1500, using nperseg = 1500
#   return _func(*args, **kwargs)
# Plotting power spectral density (dB=True).
# Polyphase resampling neighborhood: ±2 input samples
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower transition bandwidth: 0.50 Hz
# - Upper transition bandwidth: 0.50 Hz
# - Filter length: 1651 samples (6.604 s)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 825 samples (3.300 s)
# 2025-12-15 03:00:00,399 - spectral.annotation - INFO - Running PyPREP on 204 channels at 125.0Hz.
# Setting up high-pass filter at 1 Hz
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 413 samples (3.304 s)
# Executing RANSAC
# This may take a while, so be patient...
# Finding optimal chunk size : 204
# Total # of chunks: 1
# Current chunk:
# 1
# RANSAC done!
# Found 1 uniquely bad channels:
#
# 0 by NaN: []
#
# 0 by flat: []
#
# 0 by deviation: []
#
# 1 by HF noise: ['E11']
#
# 0 by correlation: []
#
# 0 by SNR: []
#
# 0 by dropout: []
#
# 0 by RANSAC: []
#
# 0 by manual: []
# 2025-12-15 03:00:09,692 - spectral.annotation - INFO - PyPREP identified 1 unique bad channels.
# 2025-12-15 03:00:09,695 - spectral.annotation - INFO - Raw object updated. Total bad channels: 1
# Writing /Users/daniel/PhD/Projects/psd-paths/data/derrivatives/sub-119/preprocessed/119_raw_annotated_filtered_raw.fif
# Closing /Users/daniel/PhD/Projects/psd-paths/data/derrivatives/sub-119/preprocessed/119_raw_annotated_filtered_raw.fif
# [done]
# Setting 13233 of 73608 (17.98%) samples to NaN, retaining 60375 (82.02%) samples.
# Effective window size : 8.192 (s)
# At least one good data span is shorter than n_per_seg, and will be analyzed with a shorter window than the rest of the file.
# Plotting power spectral density (dB=True).
# /Users/daniel/PhD/Projects/psd-paths/.venv/lib/python3.13/site-packages/mne/time_frequency/psd.py:291: UserWarning: nperseg = 2048 is greater than input length  = 375, using nperseg = 375
#   return _func(*args, **kwargs)
# /Users/daniel/PhD/Projects/psd-paths/.venv/lib/python3.13/site-packages/mne/time_frequency/psd.py:291: UserWarning: nperseg = 2048 is greater than input length  = 375, using nperseg = 375
#   return _func(*args, **kwargs)
# /Users/daniel/PhD/Projects/psd-paths/.venv/lib/python3.13/site-packages/mne/time_frequency/psd.py:291: UserWarning: nperseg = 2048 is greater than input length  = 375, using nperseg = 375
#   return _func(*args, **kwargs)
# /Users/daniel/PhD/Projects/psd-paths/.venv/lib/python3.13/site-packages/mne/time_frequency/psd.py:291: UserWarning: nperseg = 2048 is greater than input length  = 750, using nperseg = 750
#   return _func(*args, **kwargs)
# /Users/daniel/PhD/Projects/psd-paths/.venv/lib/python3.13/site-packages/mne/time_frequency/psd.py:291: UserWarning: nperseg = 2048 is greater than input length  = 1500, using nperseg = 1500
#   return _func(*args, **kwargs)
# /Users/daniel/PhD/Projects/psd-paths/.venv/lib/python3.13/site-packages/mne/time_frequency/psd.py:291: UserWarning: nperseg = 2048 is greater than input length  = 1125, using nperseg = 1125
#   return _func(*args, **kwargs)
# /Users/daniel/PhD/Projects/psd-paths/.venv/lib/python3.13/site-packages/mne/time_frequency/psd.py:291: UserWarning: nperseg = 2048 is greater than input length  = 750, using nperseg = 750
#   return _func(*args, **kwargs)
# /Users/daniel/PhD/Projects/psd-paths/.venv/lib/python3.13/site-packages/mne/time_frequency/psd.py:291: UserWarning: nperseg = 2048 is greater than input length  = 375, using nperseg = 375
#   return _func(*args, **kwargs)
# /Users/daniel/PhD/Projects/psd-paths/.venv/lib/python3.13/site-packages/mne/time_frequency/psd.py:291: UserWarning: nperseg = 2048 is greater than input length  = 375, using nperseg = 375
#   return _func(*args, **kwargs)
# /Users/daniel/PhD/Projects/psd-paths/.venv/lib/python3.13/site-packages/mne/time_frequency/psd.py:291: UserWarning: nperseg = 2048 is greater than input length  = 1500, using nperseg = 1500
#   return _func(*args, **kwargs)
# /Users/daniel/PhD/Projects/psd-paths/.venv/lib/python3.13/site-packages/mne/time_frequency/psd.py:291: UserWarning: nperseg = 2048 is greater than input length  = 1500, using nperseg = 1500
#   return _func(*args, **kwargs)
# /Users/daniel/PhD/Projects/psd-paths/.venv/lib/python3.13/site-packages/mne/time_frequency/psd.py:291: UserWarning: nperseg = 2048 is greater than input length  = 375, using nperseg = 375
#   return _func(*args, **kwargs)
# /Users/daniel/PhD/Projects/psd-paths/.venv/lib/python3.13/site-packages/mne/time_frequency/psd.py:291: UserWarning: nperseg = 2048 is greater than input length  = 375, using nperseg = 375
#   return _func(*args, **kwargs)
# /Users/daniel/PhD/Projects/psd-paths/.venv/lib/python3.13/site-packages/mne/time_frequency/psd.py:291: UserWarning: nperseg = 2048 is greater than input length  = 1875, using nperseg = 1875
#   return _func(*args, **kwargs)
# /Users/daniel/PhD/Projects/psd-paths/.venv/lib/python3.13/site-packages/mne/time_frequency/psd.py:291: UserWarning: nperseg = 2048 is greater than input length  = 1500, using nperseg = 1500
#   return _func(*args, **kwargs)
# /Users/daniel/PhD/Projects/psd-paths/.venv/lib/python3.13/site-packages/mne/time_frequency/psd.py:291: UserWarning: nperseg = 2048 is greater than input length  = 1500, using nperseg = 1500
#   return _func(*args, **kwargs)
# /Users/daniel/PhD/Projects/psd-paths/.venv/lib/python3.13/site-packages/mne/time_frequency/psd.py:291: UserWarning: nperseg = 2048 is greater than input length  = 1875, using nperseg = 1875
#   return _func(*args, **kwargs)
# Saving report to : /Users/daniel/PhD/Projects/psd-paths/outputs/reports/sub-119/sub-119_preprocessing_report.html
# 2025-12-15 03:00:11,481 - hamilton.base - WARNING - It appears no Pandas index type was detected (ignore this warning if you're using DASK for now.) Please check whether the dataframe created matches what what you expect to happen.

# %%
fig = results["raw_potatoed"].iloc[0].plot(scalings='auto', show=True,  butterfly=True)
# Out:
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
standard_scalings = {
    "eeg": 60e-6,  # 40 µV (Good for clean brainwaves)
    "ecg": 500e-6,  # 500 µV (ECG is naturally much larger)
    "eog": 150e-6,
}
fig = results["raw_filtered"].iloc[0].plot(scalings=standard_scalings, show=True,  butterfly=True)
# Out:
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
display(results["plot_raw_psd"].iloc[0] )

# %%
display(results["plot_filtered_psd"].iloc[0] )

# %%
sensor_plot = results["raw_annotated_pyprep"].iloc[0].plot_sensors(show_names=True)
